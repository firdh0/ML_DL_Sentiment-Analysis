# %% [markdown]
# # 📢 File explanation!!

# %% [markdown]
# # 🎯 **Step 0: Import library**
# ---

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import json

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
plt.style.use('seaborn')
# Out:
# <ipython-input-2-4a43041a1d49>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 🎯 **Step 1: Load Dataset**
# ---

# %%
path = '/content/drive/MyDrive/INDONESIA AI/Sentiment Analysis/Dataset/df_tweet_after_preprocessing.csv'

df_tweet = pd.read_csv(path)

df_tweet.head()
# Out:
#   sentimen                                              tweet  \
# 0  negatif  Kata @prabowo Indonesia tidak dihargai bangsa ...
# 1   netral  Batuan Langka, Tasbih Jokowi Hadiah dari Habib...
# 2   netral  Di era Jokowi, ekonomi Indonesia semakin baik....
# 3  positif  Bagi Sumatera Selatan, Asian Games berdampak p...
# 4  negatif  Negara kita ngutang buat bngun infrastruktur y...
#
#                                          clean_tweet  \
# 0  ['kata', 'prabowo', 'indonesia', 'tidak', 'har...
# 1  ['batu', 'langka', 'tasbih', 'jokowi', 'hadiah...
# 2  ['era', 'jokowi', 'ekonomi', 'indonesia', 'mak...
# 3  ['sumatera', 'selatan', 'asian', 'games', 'dam...
# 4  ['negara', 'hutang', 'buat', 'bangun', 'infras...
#
#                                 clean_tweet_sentence
# 0  kata prabowo indonesia tidak harga bangsa asin...
# 1  batu langka tasbih jokowi hadiah habib luthfi ...
# 2            era jokowi ekonomi indonesia makin baik
# 3  sumatera selatan asian games dampak ekonomi la...
# 4  negara hutang buat bangun infrastruktur pakai ...

# %% [markdown]
# # 🎯 **Step 2: Split data into feature and label**
# ---

# %%
X = df_tweet['clean_tweet_sentence']

y = df_tweet['sentimen']

# %% [markdown]
# # 🎯 **Step 3: Processing X**
# ---

# %% [markdown]
# ## ✨ 3.1 - Create Char Level Corpus for Tokenizing and Padding

# %%
X = [str(text) for text in X]

tokenizer_char_level = Tokenizer(num_words=None, oov_token='<OOV>', char_level=True)
tokenizer_char_level.fit_on_texts(X)

# %%
len(tokenizer_char_level.word_index)
# Out:
# 39

# %%
first_10_items = {k: tokenizer_char_level.word_index[k] for k in list(tokenizer_char_level.word_index)[:10]}
print(first_10_items)
# Out:
# {'<OOV>': 1, 'a': 2, ' ': 3, 'i': 4, 'n': 5, 'k': 6, 'o': 7, 'e': 8, 'r': 9, 's': 10}

# %%
tokenizer_char_json = tokenizer_char_level.to_json()

# Menyimpan representasi JSON ke dalam sebuah file
with open('/content/drive/MyDrive/INDONESIA AI/Sentiment Analysis/Tokenizer/tokenizer_char_level.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_char_json))

# %% [markdown]
# ## ✨ 3.1 - Create Word Level Corpus for Tokenizing and Padding

# %%
tokenizer_word_level = Tokenizer(num_words=None, oov_token='<OOV>')
tokenizer_word_level.fit_on_texts(X)

# %%
len(tokenizer_word_level.word_index)
# Out:
# 4964

# %%
first_10_items = {k: tokenizer_word_level.word_index[k] for k in list(tokenizer_word_level.word_index)[:10]}
print(first_10_items)
# Out:
# {'<OOV>': 1, 'ekonomi': 2, 'tidak': 3, 'jokowi': 4, 'prabowo': 5, 'gaji': 6, 'pak': 7, 'harga': 8, 'indonesia': 9, 'jadi': 10}

# %%
tokenizer_word_json = tokenizer_word_level.to_json()

# Menyimpan representasi JSON ke dalam sebuah file
with open('/content/drive/MyDrive/INDONESIA AI/Sentiment Analysis/Tokenizer/tokenizer_word_level.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_word_json))
